# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
temporal_data=pd.read_csv('temporal.csv')
temporal_data.head()
# Out:
#           Mes  data science  machine learning  deep learning  categorical
# 0  01-01-2004            12                18              4            1
# 1  01-02-2004            12                21              2            1
# 2  01-03-2004             9                21              2            1
# 3  01-04-2004            10                16              4            1
# 4  01-05-2004             7                14              3            1

# %%
temporal_data.describe()
# Out:
#        data science  machine learning  deep learning  categorical
# count    194.000000        194.000000     194.000000   194.000000
# mean      20.953608         27.396907      24.231959     0.257732
# std       23.951006         28.091490      34.476887     0.438517
# min        4.000000          7.000000       1.000000     0.000000
# 25%        6.000000          9.000000       2.000000     0.000000
# 50%        8.000000         13.000000       3.000000     0.000000
# 75%       26.750000         31.500000      34.000000     1.000000
# max      100.000000        100.000000     100.000000     1.000000

# %%
temporal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Mes               194 non-null    object
#  1   data science      194 non-null    int64
#  2   machine learning  194 non-null    int64
#  3   deep learning     194 non-null    int64
#  4   categorical       194 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB

# %%
temporal_data.shape
# Out:
# (194, 5)

# %%
temporal_data['Mes']=pd.to_datetime(temporal_data['Mes'])
temporal_data.head()
# Out:
#          Mes  data science  machine learning  deep learning  categorical
# 0 2004-01-01            12                18              4            1
# 1 2004-01-02            12                21              2            1
# 2 2004-01-03             9                21              2            1
# 3 2004-01-04            10                16              4            1
# 4 2004-01-05             7                14              3            1

# %% [markdown]
# we can highlight max and min values with colors.

# %%
format_dict={'Mes':'{:%m-%y}'}
#simplified format dictionary with values that do make sense for our data
temporal_data.head().style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#FF0000')
# Out:
# <style type="text/css">
# #T_a61b7_row0_col0, #T_a61b7_row1_col3, #T_a61b7_row2_col3, #T_a61b7_row4_col1, #T_a61b7_row4_col2 {
#   background-color: #FF0000;
# }
# #T_a61b7_row0_col1, #T_a61b7_row0_col3, #T_a61b7_row1_col1, #T_a61b7_row1_col2, #T_a61b7_row2_col2, #T_a61b7_row3_col3, #T_a61b7_row4_col0 {
#   background-color: darkgreen;
# }
# #T_a61b7_row0_col4, #T_a61b7_row1_col4, #T_a61b7_row2_col4, #T_a61b7_row3_col4, #T_a61b7_row4_col4 {
#   background-color: darkgreen;
#   background-color: #FF0000;
# }
# </style>
# <table id="T_a61b7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Mes</th>
#       <th class="col_heading level0 col1" >data science</th>
#       <th class="col_heading level0 col2" >machine learning</th>
#       <th class="col_heading level0 col3" >deep learning</th>
#       <th class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a61b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a61b7_row0_col0" class="data row0 col0" >01-04</td>
#       <td id="T_a61b7_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_a61b7_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_a61b7_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_a61b7_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a61b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a61b7_row1_col0" class="data row1 col0" >01-04</td>
#       <td id="T_a61b7_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_a61b7_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_a61b7_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_a61b7_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a61b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a61b7_row2_col0" class="data row2 col0" >01-04</td>
#       <td id="T_a61b7_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_a61b7_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_a61b7_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_a61b7_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a61b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a61b7_row3_col0" class="data row3 col0" >01-04</td>
#       <td id="T_a61b7_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_a61b7_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_a61b7_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_a61b7_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a61b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a61b7_row4_col0" class="data row4 col0" >01-04</td>
#       <td id="T_a61b7_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_a61b7_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_a61b7_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_a61b7_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We use a color gradient to diplay the data values.

# %%
temporal_data.head(10).style.format(format_dict).background_gradient(subset=['data science','machine learning'],cmap='BuGn')
# Out:
# <style type="text/css">
# #T_26787_row0_col1, #T_26787_row1_col1, #T_26787_row1_col2, #T_26787_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_26787_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_26787_row2_col1, #T_26787_row5_col1, #T_26787_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_26787_row3_col1, #T_26787_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_26787_row3_col2, #T_26787_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_26787_row4_col1, #T_26787_row4_col2, #T_26787_row7_col1, #T_26787_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_26787_row5_col2, #T_26787_row8_col2, #T_26787_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_26787_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_26787_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Mes</th>
#       <th class="col_heading level0 col1" >data science</th>
#       <th class="col_heading level0 col2" >machine learning</th>
#       <th class="col_heading level0 col3" >deep learning</th>
#       <th class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26787_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26787_row0_col0" class="data row0 col0" >01-04</td>
#       <td id="T_26787_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_26787_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_26787_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_26787_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26787_row1_col0" class="data row1 col0" >01-04</td>
#       <td id="T_26787_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_26787_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_26787_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_26787_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26787_row2_col0" class="data row2 col0" >01-04</td>
#       <td id="T_26787_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_26787_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_26787_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_26787_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26787_row3_col0" class="data row3 col0" >01-04</td>
#       <td id="T_26787_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_26787_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_26787_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_26787_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26787_row4_col0" class="data row4 col0" >01-04</td>
#       <td id="T_26787_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_26787_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_26787_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_26787_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26787_row5_col0" class="data row5 col0" >01-04</td>
#       <td id="T_26787_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_26787_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_26787_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_26787_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26787_row6_col0" class="data row6 col0" >01-04</td>
#       <td id="T_26787_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_26787_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_26787_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_26787_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26787_row7_col0" class="data row7 col0" >01-04</td>
#       <td id="T_26787_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_26787_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_26787_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_26787_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_26787_row8_col0" class="data row8 col0" >01-04</td>
#       <td id="T_26787_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_26787_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_26787_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_26787_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_26787_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_26787_row9_col0" class="data row9 col0" >01-04</td>
#       <td id="T_26787_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_26787_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_26787_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_26787_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# we can also display the data values with bars

# %%
temporal_data.head().style.format(format_dict).bar(color='red',subset=['data science','deep learning'])
# Out:
# <style type="text/css">
# #T_5b79a_row0_col1, #T_5b79a_row0_col3, #T_5b79a_row1_col1, #T_5b79a_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 100.0%, transparent 100.0%);
# }
# #T_5b79a_row1_col3, #T_5b79a_row2_col3, #T_5b79a_row4_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_5b79a_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 40.0%, transparent 40.0%);
# }
# #T_5b79a_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 60.0%, transparent 60.0%);
# }
# #T_5b79a_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_5b79a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Mes</th>
#       <th class="col_heading level0 col1" >data science</th>
#       <th class="col_heading level0 col2" >machine learning</th>
#       <th class="col_heading level0 col3" >deep learning</th>
#       <th class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b79a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b79a_row0_col0" class="data row0 col0" >01-04</td>
#       <td id="T_5b79a_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_5b79a_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_5b79a_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_5b79a_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b79a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b79a_row1_col0" class="data row1 col0" >01-04</td>
#       <td id="T_5b79a_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_5b79a_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_5b79a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_5b79a_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b79a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b79a_row2_col0" class="data row2 col0" >01-04</td>
#       <td id="T_5b79a_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_5b79a_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_5b79a_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_5b79a_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b79a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b79a_row3_col0" class="data row3 col0" >01-04</td>
#       <td id="T_5b79a_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_5b79a_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_5b79a_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_5b79a_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b79a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b79a_row4_col0" class="data row4 col0" >01-04</td>
#       <td id="T_5b79a_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_5b79a_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_5b79a_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_5b79a_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
temporal_data.head(10).style.format(format_dict).background_gradient(subset=['data science','machine learning'],cmap='BuGn').highlight_max(color='yellow')
# Out:
# <style type="text/css">
# #T_99dac_row0_col1, #T_99dac_row1_col1, #T_99dac_row1_col2, #T_99dac_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_99dac_row0_col2 {
#   background-color: #51b689;
#   color: #f1f1f1;
# }
# #T_99dac_row0_col3, #T_99dac_row0_col4, #T_99dac_row1_col4, #T_99dac_row2_col4, #T_99dac_row3_col3, #T_99dac_row3_col4, #T_99dac_row4_col4, #T_99dac_row5_col4, #T_99dac_row6_col4, #T_99dac_row7_col4, #T_99dac_row8_col3, #T_99dac_row8_col4, #T_99dac_row9_col0, #T_99dac_row9_col3, #T_99dac_row9_col4 {
#   background-color: yellow;
# }
# #T_99dac_row2_col1, #T_99dac_row5_col1, #T_99dac_row6_col1 {
#   background-color: #8fd4c2;
#   color: #000000;
# }
# #T_99dac_row3_col1, #T_99dac_row8_col1 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_99dac_row3_col2, #T_99dac_row6_col2 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_99dac_row4_col1, #T_99dac_row4_col2, #T_99dac_row7_col1, #T_99dac_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_99dac_row5_col2, #T_99dac_row8_col2, #T_99dac_row9_col2 {
#   background-color: #84cfb9;
#   color: #000000;
# }
# #T_99dac_row9_col1 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# </style>
# <table id="T_99dac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Mes</th>
#       <th class="col_heading level0 col1" >data science</th>
#       <th class="col_heading level0 col2" >machine learning</th>
#       <th class="col_heading level0 col3" >deep learning</th>
#       <th class="col_heading level0 col4" >categorical</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99dac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99dac_row0_col0" class="data row0 col0" >01-04</td>
#       <td id="T_99dac_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_99dac_row0_col2" class="data row0 col2" >18</td>
#       <td id="T_99dac_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_99dac_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99dac_row1_col0" class="data row1 col0" >01-04</td>
#       <td id="T_99dac_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_99dac_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_99dac_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_99dac_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99dac_row2_col0" class="data row2 col0" >01-04</td>
#       <td id="T_99dac_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_99dac_row2_col2" class="data row2 col2" >21</td>
#       <td id="T_99dac_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_99dac_row2_col4" class="data row2 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99dac_row3_col0" class="data row3 col0" >01-04</td>
#       <td id="T_99dac_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_99dac_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_99dac_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_99dac_row3_col4" class="data row3 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99dac_row4_col0" class="data row4 col0" >01-04</td>
#       <td id="T_99dac_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_99dac_row4_col2" class="data row4 col2" >14</td>
#       <td id="T_99dac_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_99dac_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99dac_row5_col0" class="data row5 col0" >01-04</td>
#       <td id="T_99dac_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_99dac_row5_col2" class="data row5 col2" >17</td>
#       <td id="T_99dac_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_99dac_row5_col4" class="data row5 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99dac_row6_col0" class="data row6 col0" >01-04</td>
#       <td id="T_99dac_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_99dac_row6_col2" class="data row6 col2" >16</td>
#       <td id="T_99dac_row6_col3" class="data row6 col3" >3</td>
#       <td id="T_99dac_row6_col4" class="data row6 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99dac_row7_col0" class="data row7 col0" >01-04</td>
#       <td id="T_99dac_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_99dac_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_99dac_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_99dac_row7_col4" class="data row7 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99dac_row8_col0" class="data row8 col0" >01-04</td>
#       <td id="T_99dac_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_99dac_row8_col2" class="data row8 col2" >17</td>
#       <td id="T_99dac_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_99dac_row8_col4" class="data row8 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_99dac_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99dac_row9_col0" class="data row9 col0" >01-04</td>
#       <td id="T_99dac_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_99dac_row9_col2" class="data row9 col2" >17</td>
#       <td id="T_99dac_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_99dac_row9_col4" class="data row9 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # pandas profiling

# %%
import pandas as pd 

import pandas_profiling as pp

# %%
dct = {'ID': {0: 23, 1: 43, 2: 12, 3: 13, 4: 67, 5: 89, 6: 90, 7: 56,8: 34},  

       'Name': {0: 'Ram', 1: 'Deep', 2: 'Yash', 3: 'Aman', 4: 'Arjun', 5: 'Aditya', 6: 'Divya', 7: 'Chalsea', 8: 'Akash' },  

       'Marks': {0: 89, 1: 97, 2: 45, 3: 78, 4: 56, 5: 76, 6: 100, 7: 87, 8: 81},  

       'Grade': {0: 'B', 1: 'A', 2: 'F', 3: 'C', 4: 'E', 5: 'C', 6: 'A', 7: 'B', 8: 'B'} 

      }

# %%
data = pd.DataFrame(dct) 

print(data)
# Out:
#    ID     Name  Marks Grade
# 0  23      Ram     89     B
# 1  43     Deep     97     A
# 2  12     Yash     45     F
# 3  13     Aman     78     C
# 4  67    Arjun     56     E
# 5  89   Aditya     76     C
# 6  90    Divya    100     A
# 7  56  Chalsea     87     B
# 8  34    Akash     81     B

# %%
profile = pp.ProfileReport(data) 

profile.to_file("output.html")
# Out:
# Summarize dataset:   0%|          | 0/17 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
plt.plot(temporal_data['Mes'],temporal_data['data science'], label='data science')
#The parameter label is to indicate the legend

# %%
plt.plot(temporal_data['Mes'], temporal_data['data science'], label='data science')
plt.plot(temporal_data['Mes'], temporal_data['machine learning'], label='machine learning')
plt.plot(temporal_data['Mes'], temporal_data['deep learning'], label='deep learning')

# %% [markdown]
# it is not clear which variable each color represents

# %%
plt.plot(temporal_data['Mes'], temporal_data['data science'], label='data science')
plt.plot(temporal_data['Mes'], temporal_data['machine learning'], label='machine learning')
plt.plot(temporal_data['Mes'], temporal_data['deep learning'], label='deep learning')
plt.xlabel('Date')
plt.ylabel('popularity')
plt.title('popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %%
fig, axes=plt.subplots(2,2)
axes[0,0].hist(temporal_data['data science'])
axes[0,1].scatter(temporal_data['Mes'], temporal_data['data science'])
axes[1,0].plot(temporal_data['Mes'], temporal_data['machine learning'])
axes[1,1].plot(temporal_data['Mes'], temporal_data['deep learning'])

# %% [markdown]
# we can draw the graph with different styles for the points of each variable

# %%
plt.plot(temporal_data['Mes'], temporal_data['data science'], 'r-')
plt.plot(temporal_data['Mes'], temporal_data['machine learning']*2, 'bs')
plt.plot(temporal_data['Mes'], temporal_data['deep learning']*3, 'g^' )

# %% [markdown]
# Now let’s see a few examples of the different graphics we can do with Matplotlib. We start with a scatterplot:

# %%
plt.scatter(temporal_data['data science'], temporal_data['machine learning'])

# %%
plt.bar(temporal_data['Mes'], temporal_data['machine learning'], width=20)
# Out:
# <BarContainer object of 194 artists>

# %% [markdown]
# We can add a text to the graphic, we indicate the position of the text in the same units that we see in the graphic. In the text, we can even add special characters following the TeX language.
#
# We can also add markers that point to a particular point on the graph.

# %%
plt.plot(temporal_data['Mes'], temporal_data['data science'], label='data science')
plt.plot(temporal_data['Mes'], temporal_data['machine learning'], label='machine learning')
plt.plot(temporal_data['Mes'], temporal_data['deep learning'], label='deep learning')
plt.xlabel('Date')
plt.ylabel('popularity')
plt.title('popularity of AI terms by date')
plt.grid(True)
plt.text(x=pd.to_datetime('2010-01-01'),y=80, s=r'$\lambda=1, r^2=0.8$')
plt.annotate('Notice Something?',xy=(pd.to_datetime('2014-01-01'),30),
             xytext=(pd.to_datetime('2006-01-01'),50),
             arrowprops={'facecolor':'red', 'shrink':0.05})
# Out:
# Text(2006-01-01 00:00:00, 50, 'Notice Something?')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
sns.set()
sns.scatterplot(temporal_data['Mes'],temporal_data['data science'])
# Out:
# C:\Users\nagan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Mes', ylabel='data science'>

# %%
sns.relplot(x='Mes',y='deep learning',hue='data science',
            size='machine learning',col='categorical',data=temporal_data)

# %%
sns.heatmap(temporal_data.corr(),annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(temporal_data)

# %%
sns.pairplot(temporal_data,hue='categorical')

# %%
sns.catplot(x='categorical',y='data science',kind='violin',data='temporal_data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-fff1df99ac29> in <module>
# ----> 1 sns.catplot(x='categorical',y='data science',kind='violin',data='temporal_data')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     142             # See if we need to get variables from `data`
#     143             if data is not None:
# --> 144                 x = data.get(x, x)
#     145                 y = data.get(y, y)
#     146                 hue = data.get(hue, hue)
#
# AttributeError: 'str' object has no attribute 'get'

# %%
fig,axes=plt.subplots(1,2,sharey=True,figsize=(8,4))
sns.scatterplot(x="Mes",y="deep learning",hue="categorical",data=temporal_data,ax=axes[0])
axes[0].set_title('Deep Learning')
sns.scatterplot(x="Mes",y="machine learning",hue="categorical",data=temporal_data,ax=axes[1])
axes[1].set_title('Machine learning')
# Out:
# Text(0.5, 1.0, 'Machine learning')

# %% [markdown]
# # Altair

# %%
pip install folium
# Out:
# Collecting foliumNote: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
#   Downloading folium-0.13.0-py2.py3-none-any.whl (96 kB)
#      -------------------------------------- 96.5/96.5 kB 501.6 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\nagan\anaconda3\lib\site-packages (from folium) (1.19.1)
# Requirement already satisfied: requests in c:\users\nagan\anaconda3\lib\site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\nagan\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nagan\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.13.0

# %%
import folium
m1=folium.Map(location=[41.38,2.17],titles='openstreetmap',zoom_start=18)
m1.save('map1.html')

# %%
#Folium is a library that allows us to draw maps and markers

# %%
m2=folium.Map(location=[41.38,2.17],tiles='openstreetamap',zoom_start=16)
folium.Marker([41.38,2.176],popup='<i>You can use whatever HTML code you want</i>',tooltip='click here').add_to(m2)
folium.Marker([41.38,2.174],popup='<b>You can use whatever HTML code you want</b>',tooltip='dont click here').add_to(m2)
m2.save('map2.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-368de6210554> in <module>
# ----> 1 m2=folium.Map(location=[41.38,2.17],tiles='openstreetamap',zoom_start=16)
#       2 folium.Marker([41.38,2.176],popup='<i>You can use whatever HTML code you want</i>',tooltip='click here').add_to(m2)
#       3 folium.Marker([41.38,2.174],popup='<b>You can use whatever HTML code you want</b>',tooltip='dont click here').add_to(m2)
#       4 m2.save('map2.html')
#
# ~\anaconda3\lib\site-packages\folium\folium.py in __init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, **kwargs)
#     284
#     285         if tiles:
# --> 286             tile_layer = TileLayer(tiles=tiles, attr=attr,
#     287                                    min_zoom=min_zoom, max_zoom=max_zoom)
#     288             self.add_child(tile_layer, name=tile_layer.tile_name)
#
# ~\anaconda3\lib\site-packages\folium\raster_layers.py in __init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     107             self.tiles = tiles
#     108             if not attr:
# --> 109                 raise ValueError('Custom tiles must have an attribution.')
#     110
#     111         self.options = parse_options(
#
# ValueError: Custom tiles must have an attribution.

# %%
pip install geopandas
# Out:
# Collecting geopandasNote: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
#   Downloading geopandas-0.12.1-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 748.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in c:\users\nagan\anaconda3\lib\site-packages (from geopandas) (1.3.2)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp38-cp38-win_amd64.whl (21.7 MB)
#      ---------------------------------------- 21.7/21.7 MB 2.8 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.0-cp38-cp38-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\nagan\anaconda3\lib\site-packages (from geopandas) (20.4)
# Collecting shapely>=1.7
#   Downloading Shapely-1.8.5.post1-cp38-cp38-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\nagan\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (50.3.1.post20201107)
# Requirement already satisfied: certifi in c:\users\nagan\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2020.6.20)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.7 in c:\users\nagan\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click>=4.0 in c:\users\nagan\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in c:\users\nagan\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\nagan\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\nagan\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2020.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nagan\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.19.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nagan\anaconda3\lib\site-packages (from packaging->geopandas) (2.4.7)
# Installing collected packages: shapely, pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.1 munch-2.5.0 pyproj-3.4.0 shapely-1.8.5.post1

# %%
import pandas as pd
from geopandas.tools import geocode
map_data=pd.read_csv('maps.csv')
map_data.dropna(axis=0,inplace=True)
map_data['geometry'] = geocode(map_data['País'],provider='nominatim')['geometry']
map_data['Latitude']=map_data['geometry'].apply(lambda l: l.y)
map_data['Longitude']=mpa_data['geometry'].apply(lambda l: l.x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'País'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ad659e9be4b8> in <module>
#       3 map_data=pd.read_csv('maps.csv')
#       4 map_data.dropna(axis=0,inplace=True)
# ----> 5 map_data['geometry'] = geocode(map_data['País'],provider='nominatim')['geometry']
#       6 map_data['Latitude']=map_data['geometry'].apply(lambda l: l.y)
#       7 map_data['Longitude']=mpa_data['geometry'].apply(lambda l: l.x)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'País'

# %%
m3 = folium.Map(location=[39.326234,-4.838065], tiles='openstreetmap', zoom_start=3)
def color_producer(val):
    if val <= 50:
        return 'red'
    else:
        return 'green'
for i in range(0,len(map_data)):
    folium.Circle(location=[map_data.iloc[i]['Latitude'], map_data.iloc[i]['Longitude']],
    radius=5000*map_data.iloc[i]['data science'],
    color=color_producer(map_data.iloc[i]['data science'])).add_to(m3)
m3.save('map3.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-4735bac35117> in <module>
#       6         return 'green'
#       7 for i in range(0,len(map_data)):
# ----> 8     folium.Circle(location=[map_data.iloc[i]['Latitude'], map_data.iloc[i]['Longitude']],
#       9     radius=5000*map_data.iloc[i]['data science'],
#      10     color=color_producer(map_data.iloc[i]['data science'])).add_to(m3)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Latitude'

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\nagan\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\users\nagan\anaconda3\lib\site-packages (from folium) (1.19.1)
# Requirement already satisfied: requests in c:\users\nagan\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\nagan\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in c:\users\nagan\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\nagan\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nagan\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
